# %%
import gensim
import os
import collections
import smart_open
import random

# %%
test_data_dir = '{}'.format(os.sep).join([gensim.__path__[0], 'test', 'test_data'])
lee_train_file = test_data_dir + os.sep + 'lee_background.cor'
lee_test_file = test_data_dir + os.sep + 'lee.cor'

# %%
def read_corpus(fname, tokens_only=False):
    with smart_open.smart_open(fname, encoding="iso-8859-1") as f:
        for i, line in enumerate(f):
            if tokens_only:
                yield gensim.utils.simple_preprocess(line)
            else:
                # For training data, add tags
                yield gensim.models.doc2vec.TaggedDocument(gensim.utils.simple_preprocess(line), [i])

# %%
train_corpus = list(read_corpus(lee_train_file))
test_corpus = list(read_corpus(lee_test_file, tokens_only=True))
# Out:
# /home/infyblr/anaconda3/envs/surveybrain/lib/python3.6/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
train_corpus[:2]
# Out:
# [TaggedDocument(words=['hundreds', 'of', 'people', 'have', 'been', 'forced', 'to', 'vacate', 'their', 'homes', 'in', 'the', 'southern', 'highlands', 'of', 'new', 'south', 'wales', 'as', 'strong', 'winds', 'today', 'pushed', 'huge', 'bushfire', 'towards', 'the', 'town', 'of', 'hill', 'top', 'new', 'blaze', 'near', 'goulburn', 'south', 'west', 'of', 'sydney', 'has', 'forced', 'the', 'closure', 'of', 'the', 'hume', 'highway', 'at', 'about', 'pm', 'aedt', 'marked', 'deterioration', 'in', 'the', 'weather', 'as', 'storm', 'cell', 'moved', 'east', 'across', 'the', 'blue', 'mountains', 'forced', 'authorities', 'to', 'make', 'decision', 'to', 'evacuate', 'people', 'from', 'homes', 'in', 'outlying', 'streets', 'at', 'hill', 'top', 'in', 'the', 'new', 'south', 'wales', 'southern', 'highlands', 'an', 'estimated', 'residents', 'have', 'left', 'their', 'homes', 'for', 'nearby', 'mittagong', 'the', 'new', 'south', 'wales', 'rural', 'fire', 'service', 'says', 'the', 'weather', 'conditions', 'which', 'caused', 'the', 'fire', 'to', 'burn', 'in', 'finger', 'formation', 'have', 'now', 'eased', 'and', 'about', 'fire', 'units', 'in', 'and', 'around', 'hill', 'top', 'are', 'optimistic', 'of', 'defending', 'all', 'properties', 'as', 'more', 'than', 'blazes', 'burn', 'on', 'new', 'year', 'eve', 'in', 'new', 'south', 'wales', 'fire', 'crews', 'have', 'been', 'called', 'to', 'new', 'fire', 'at', 'gunning', 'south', 'of', 'goulburn', 'while', 'few', 'details', 'are', 'available', 'at', 'this', 'stage', 'fire', 'authorities', 'says', 'it', 'has', 'closed', 'the', 'hume', 'highway', 'in', 'both', 'directions', 'meanwhile', 'new', 'fire', 'in', 'sydney', 'west', 'is', 'no', 'longer', 'threatening', 'properties', 'in', 'the', 'cranebrook', 'area', 'rain', 'has', 'fallen', 'in', 'some', 'parts', 'of', 'the', 'illawarra', 'sydney', 'the', 'hunter', 'valley', 'and', 'the', 'north', 'coast', 'but', 'the', 'bureau', 'of', 'meteorology', 'claire', 'richards', 'says', 'the', 'rain', 'has', 'done', 'little', 'to', 'ease', 'any', 'of', 'the', 'hundred', 'fires', 'still', 'burning', 'across', 'the', 'state', 'the', 'falls', 'have', 'been', 'quite', 'isolated', 'in', 'those', 'areas', 'and', 'generally', 'the', 'falls', 'have', 'been', 'less', 'than', 'about', 'five', 'millimetres', 'she', 'said', 'in', 'some', 'places', 'really', 'not', 'significant', 'at', 'all', 'less', 'than', 'millimetre', 'so', 'there', 'hasn', 'been', 'much', 'relief', 'as', 'far', 'as', 'rain', 'is', 'concerned', 'in', 'fact', 'they', 've', 'probably', 'hampered', 'the', 'efforts', 'of', 'the', 'firefighters', 'more', 'because', 'of', 'the', 'wind', 'gusts', 'that', 'are', 'associated', 'with', 'those', 'thunderstorms'], tags=[0]),
#  TaggedDocument(words=['indian', 'security', 'forces', 'have', 'shot', 'dead', 'eight', 'suspected', 'militants', 'in', 'night', 'long', 'encounter', 'in', 'southern', 'kashmir', 'the', 'shootout', 'took', 'place', 'at', 'dora', 'village', 'some', 'kilometers', 'south', 'of', 'the', 'kashmiri', 'summer', 'capital', 'srinagar', 'the', 'deaths', 'came', 'as', 'pakistani', 'police', 'arrested', 'more', 'than', 'two', 'dozen', 'militants', 'from', 'extremist', 'groups', 'accused', 'of', 'staging', 'an', 'attack', 'on', 'india', 'parliament', 'india', 'has', 'accused', 'pakistan', 'based', 'lashkar', 'taiba', 'and', 'jaish', 'mohammad', 'of', 'carrying', 'out', 'the', 'attack', 'on', 'december', 'at', 'the', 'behest', 'of', 'pakistani', 'military', 'intelligence', 'military', 'tensions', 'have', 'soared', 'since', 'the', 'raid', 'with', 'both', 'sides', 'massing', 'troops', 'along', 'their', 'border', 'and', 'trading', 'tit', 'for', 'tat', 'diplomatic', 'sanctions', 'yesterday', 'pakistan', 'announced', 'it', 'had', 'arrested', 'lashkar', 'taiba', 'chief', 'hafiz', 'mohammed', 'saeed', 'police', 'in', 'karachi', 'say', 'it', 'is', 'likely', 'more', 'raids', 'will', 'be', 'launched', 'against', 'the', 'two', 'groups', 'as', 'well', 'as', 'other', 'militant', 'organisations', 'accused', 'of', 'targetting', 'india', 'military', 'tensions', 'between', 'india', 'and', 'pakistan', 'have', 'escalated', 'to', 'level', 'not', 'seen', 'since', 'their', 'war'], tags=[1])]

# %%
model = gensim.models.doc2vec.Doc2Vec(vector_size=50, min_count=2, epochs=40)

# %%
model.build_vocab(train_corpus)

# %%
# %time model.train(train_corpus, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# CPU times: user 6.85 s, sys: 263 ms, total: 7.12 s
# Wall time: 3.14 s

# %%
model.infer_vector(['only', 'you', 'can', 'prevent', 'forest', 'fires','in','india'])
# Out:
# array([-0.04081251,  0.09907233, -0.14071181,  0.03392525, -0.2349259 ,
#        -0.05982138, -0.21663159,  0.0523302 , -0.29451266, -0.31753203,
#         0.04433207, -0.19574216, -0.19006261,  0.1650976 ,  0.03685386,
#         0.14444134,  0.26979125, -0.18260871, -0.04855327,  0.05406506,
#        -0.23888269, -0.04999337, -0.27730277, -0.05390741, -0.17177421,
#        -0.13757473,  0.03903996, -0.07838061, -0.24421807,  0.21927716,
#        -0.1069326 ,  0.16755913,  0.2672514 ,  0.37260506, -0.00315433,
#         0.17631668,  0.02131809,  0.00920411, -0.00371837, -0.11262745,
#        -0.04888618, -0.09076045, -0.02059839, -0.13992186, -0.07845638,
#        -0.14535038, -0.05908379, -0.13469926,  0.17294142, -0.03269662],
#       dtype=float32)

# %%
ranks = []
second_ranks = []
for doc_id in range(len(train_corpus)):
    inferred_vector = model.infer_vector(train_corpus[doc_id].words)
    sims = model.docvecs.most_similar([inferred_vector], topn=len(model.docvecs))
    rank = [docid for docid, sim in sims].index(doc_id)
    ranks.append(rank)
    
    second_ranks.append(sims[1])

# %%
collections.Counter(ranks)
# Out:
# Counter({0: 292, 1: 8})

# %%
model.n_similarity(['only', 'you', 'can', 'prevent', 'forest', 'fires','in','india'],['only', 'you', 'can', 'prevent', 'forest', 'fires','in','australia'])
# Out:
# /home/infyblr/anaconda3/envs/surveybrain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `n_similarity` (Method will be removed in 4.0.0, use self.wv.n_similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.9664531

# %%
from gensim.utils import simple_preprocess

# %%
set(model.wv.vocab.keys())
# Out:
# {'embryos',
#  'end',
#  'gathering',
#  'agencies',
#  'nato',
#  'vast',
#  'breach',
#  'government',
#  'moroccan',
#  'streets',
#  'match',
#  'boat',
#  'talks',
#  'cent',
#  'terrorists',
#  'hopman',
#  'true',
#  'legislation',
#  'unindicted',
#  'flying',
#  'five',
#  'palace',
#  'yes',
#  'settlers',
#  'senior',
#  'ring',
#  'succeed',
#  'inquiry',
#  'season',
#  'development',
#  'address',
#  'stepped',
#  'engulfed',
#  'ended',
#  'nasa',
#  'number',
#  'bid',
#  'evans',
#  'winners',
#  'trapping',
#  'managers',
#  'all',
#  'practice',
#  'lights',
#  'st',
#  'promised',
#  'harris',
#  'fighters',
#  'marked',
#  'tanks',
#  'cooperate',
#  'ashes',
#  'locals',
#  'couple',
#  'were',
#  'dominated',
#  'typhoid',
#  'taking',
#  'new',
#  'ripped',
#  'mixed',
#  'stop',
#  'szondy',
#  'prove',
#  'sweet',
#  'collins',
#  'aiming',
#  'potentially',
#  'strike',
#  'term',
#  'hiv',
#  'so',
#  'acting',
#  'emails',
#  'announce',
#  'veteran',
#  'norwegian',
#  'for',
#  'reducing',
#  'rose',
#  'apparently',
#  'detained',
#  'passenger',
#  'his',
#  'easy',
#  'targets',
#  'cigarettes',
#  'emotional',
#  'staff',
#  'conflict',
#  'coup',
#  'night',
#  'swell',
#  'autonomy',
#  'romaszko',
#  'journalist',
#  'banks',
#  'ending',
#  'flight',
#  'bulletin',
#  'bowlers',
#  'private',
#  'national',
#  'yasser',
#  'itself',
#  'spokeswoman',
#  'unpaid',
#  'afl',
#  'performed',
#  'denies',
#  'minor',
#  'heights',
#  'source',
#  'alcohol',
#  'forecaster',
#  'huegill',
#  'hamed',
#  'blow',
#  'if',
#  'longer',
#  'cole',
#  'closure',
#  'mountains',
#  'go',
#  'than',
#  'place',
#  'secure',
#  'cruising',
#  'kerry',
#  'reports',
#  'data',
#  'vessel',
#  'belief',
#  'beaten',
#  'prix',
#  'shaky',
#  'scale',
#  'provincial',
#  'river',
#  'partnership',
#  'diverted',
#  'nuclear',
#  'fewer',
#  'ruined',
#  'peace',
#  'did',
#  'manufacturing',
#  'pool',
#  'swam',
#  'heater',
#  'greens',
#  'balls',
#  'causing',
#  'normal',
#  'harrison',
#  'us',
#  'achieved',
#  'maguire',
#  'planned',
#  'arresting',
#  'harm',
#  'announcing',
#  'problem',
#  'verified',
#  'incidents',
#  'interval',
#  'energy',
#  'losing',
#  'offices',
#  'according',
#  'obligations',
#  'rule',
#  'billion',
#  'parliamentary',
#  'mass',
#  'board',
#  'principles',
#  'urgent',
#  'softer',
#  'limited',
#  'saw',
#  'ranging',
#  'causes',
#  'repayment',
#  'oversee',
#  'service',
#  'de',
#  'navy',
#  'rampage',
#  'islamabad',
#  'liabilities',
#  'begs',
#  'forthcoming',
#  'country',
#  'red',
#  'fielding',
#  'weeks',
#  'sheikh',
#  'described',
#  'holidays',
#  'lleyton',
#  'kind',
#  'meanwhile',
#  'elders',
#  'building',
#  'aviation',
#  'higher',
#  'entitlements',
#  'austar',
#  'macfarlane',
#  'serious',
#  'written',
#  'peru',
#  'professor',
#  'documents',
#  'crossing',
#  'say',
#  'reid',
#  'watching',
#  'importance',
#  'designed',
#  'reject',
#  'liverpool',
#  'media',
#  'visas',
#  'perturbed',
#  'raid',
#  'absolutely',
#  'upside',
#  'struck',
#  'death',
#  'mountainous',
#  'warplanes',
#  'lightly',
#  'searching',
#  'ham',
#  'topple',
#  'accompanied',
#  'el',
#  'economic',
#  'walz',
#  'asio',
#  'convinced',
#  'have',
#  'way',
#  'alert',
#  'faces',
#  'firefighters',
#  'followers',
#  'lali',
#  'financial',
#  'increased',
#  'question',
#  'treason',
#  'suspected',
#  'preventable',
#  'ascertain',
#  'signature',
#  'haitian',
#  'extensive',
#  'fanned',
#  'masterminding',
#  'announced',
#  'institutions',
#  'lubbers',
#  'audience',
#  'devout',
#  'ismail',
#  'classic',
#  'champion',
#  'fell',
#  'competition',
#  'chanting',
#  'catch',
#  'definitely',
#  'pat',
#  'expressed',
#  'economy',
#  'employees',
#  'daniel',
#  'fans',
#  'christian',
#  'foley',
#  'damage',
#  'phenomena',
#  'favour',
#  'goulburn',
#  'check',
#  'allegations',
#  'shortly',
#  'fate',
#  'abc',
#  'ten',
#  'secretary',
#  'canada',
#  'claimed',
#  'demonstrations',
#  'necessary',
#  'rd',
#  'named',
#  'sheldon',
#  'heads',
#  'them',
#  'hopeful',
#  'concerned',
#  'office',
#  'reconstruction',
#  'now',
#  'gorge',
#  'fear',
#  'win',
#  'shoot',
#  'marines',
#  'society',
#  'procedure',
#  'everything',
#  'travel',
#  'yesterday',
#  'using',
#  'outlook',
#  'secret',
#  'drug',
#  'lawrence',
#  'hotel',
#  'disruption',
#  'videotape',
#  'park',
#  'declaring',
#  'gets',
#  'kabul',
#  'faced',
#  'average',
#  'girl',
#  'sutton',
#  'chief',
#  'flown',
#  'before',
#  'ryan',
#  'travels',
#  'kieren',
#  'snatching',
#  'british',
#  'finish',
#  'promises',
#  'ticket',
#  'suffer',
#  'airport',
#  'tension',
#  'advani',
#  'sun',
#  'investment',
#  'recalled',
#  'pressure',
#  'advice',
#  'benefit',
#  'captured',
#  'thursday',
#  'woke',
#  'casinos',
#  'casualty',
#  'hindu',
#  'allegedly',
#  'currently',
#  'helicopter',
#  'ken',
#  'elka',
#  'arrests',
#  'farewell',
#  'twin',
#  'scores',
#  'surrounding',
#  'rescued',
#  'african',
#  'laws',
#  'quite',
#  'hearing',
#  'television',
#  'full',
#  'policy',
#  'contacts',
#  'bob',
#  'franklin',
#  'pulled',
#  'experiments',
#  'agency',
#  'doesn',
#  'constitutional',
#  'memory',
#  'looking',
#  'few',
#  'cameron',
#  'special',
#  'happened',
#  'ii',
#  'an',
#  'amalgamation',
#  'model',
#  'cnn',
#  'tell',
#  'command',
#  'unidentified',
#  'trick',
#  'cosgrove',
#  'rural',
#  'solvency',
#  'diplomatic',
#  'risk',
#  'downgrade',
#  'eastern',
#  'japan',
#  'various',
#  'musharraf',
#  'random',
#  'nearest',
#  'anti',
#  'cmag',
#  'under',
#  'offered',
#  'statement',
#  'even',
#  'destroyed',
#  'armed',
#  'heavy',
#  'reduced',
#  'chemical',
#  'representatives',
#  'potts',
#  'protected',
#  'interview',
#  'offensive',
#  'gary',
#  'neville',
#  'reverend',
#  'temperatures',
#  'urging',
#  'battleground',
#  'those',
#  'schroeder',
#  'zone',
#  'independent',
#  'reporting',
#  'venue',
#  'nude',
#  'suspect',
#  'strong',
#  'bomber',
#  'cover',
#  'retreat',
#  'astronauts',
#  'salary',
#  'ferguson',
#  'read',
#  'credit',
#  'mr',
#  'mountain',
#  'seem',
#  'actions',
#  'anything',
#  'community',
#  'illness',
#  'depression',
#  'backing',
#  'hawke',
#  'saxeten',
#  'aimed',
#  'gerhard',
#  'dishonestly',
#  'squads',
#  'elimination',
#  'blazes',
#  'broken',
#  'costello',
#  'cause',
#  'yachting',
#  'effective',
#  'extremist',
#  'contact',
#  'volvo',
#  'ivf',
#  'dominic',
#  'does',
#  'rejected',
#  'arabs',
#  'fighter',
#  'estimates',
#  'incentive',
#  'civilians',
#  'why',
#  'severe',
#  'kinds',
#  'wage',
#  'pacific',
#  'carry',
#  'side',
#  'gearing',
#  'attempted',
#  'asked',
#  'subject',
#  'option',
#  'bacteria',
#  'meant',
#  'infection',
#  'motorway',
#  'including',
#  'earlier',
#  'resistant',
#  'pull',
#  'annual',
#  'antarctic',
#  'airstrikes',
#  'probably',
#  'rest',
#  'present',
#  'difficult',
#  'protesters',
#  'old',
#  'wonderful',
#  'issue',
#  'nu',
#  'proceed',
#  'actor',
#  'behari',
#  'told',
#  'mid',
#  'single',
#  'alerted',
#  'timothy',
#  'muslims',
#  'specific',
#  'haven',
#  'disease',
#  'aren',
#  'jackson',
#  'blame',
#  'airline',
#  'pictures',
#  'refugees',
#  'nobel',
#  'request',
#  'abated',
#  'daryl',
#  'over',
#  'call',
#  'examine',
#  'bases',
#  'placed',
#  'received',
#  'reminded',
#  'change',
#  'occurred',
#  'climate',
#  'islam',
#  'imf',
#  'hard',
#  'atlanta',
#  'american',
#  'where',
#  'author',
#  'abusive',
#  'producer',
#  'measures',
#  'sunshine',
#  'cars',
#  'soccer',
#  'provided',
#  'dealt',
#  'intentions',
#  'wild',
#  'dominant',
#  'stringer',
#  'multinational',
#  'training',
#  'sex',
#  'shooting',
#  'grief',
#  'malaysia',
#  'telephone',
#  'when',
#  'site',
#  'miami',
#  'alarm',
#  'trial',
#  'sri',
#  'canyoning',
#  'republican',
#  'forms',
#  'later',
#  'appealed',
#  'package',
#  'tower',
#  'evil',
#  'outsource',
#  'door',
#  'farmer',
#  'doing',
#  'osama',
#  'wholly',
#  'gillespie',
#  'nor',
#  'kevin',
#  'reading',
#  'commandos',
#  'proves',
#  'singh',
#  'down',
#  'statutory',
#  'lawyer',
#  'williams',
#  'myers',
#  'customers',
#  'information',
#  'picked',
#  'somali',
#  'outsourcing',
#  'allies',
#  'reached',
#  'gibbs',
#  'others',
#  'shot',
#  'weekend',
#  'stoppage',
#  'airlift',
#  'hass',
#  'sending',
#  'gunfire',
#  'resources',
#  'egyptian',
#  'eighth',
#  'issued',
#  'delhi',
#  'coalition',
#  'ocean',
#  'hayden',
#  'really',
#  'charged',
#  'survived',
#  'connection',
#  'sank',
#  'task',
#  'sharing',
#  'acdt',
#  'her',
#  'hostage',
#  'spinner',
#  'edge',
#  'air',
#  'own',
#  'shares',
#  'mayor',
#  'returned',
#  'dismissed',
#  'decades',
#  'teams',
#  'negligence',
#  'missing',
#  'shown',
#  'tried',
#  'strachan',
#  'neil',
#  'flood',
#  'adding',
#  'diplomacy',
#  'fence',
#  'blood',
#  'voting',
#  'fatality',
#  'dismantle',
#  'ashcroft',
#  'ricky',
#  'runs',
#  'failing',
#  'channel',
#  'determine',
#  'tour',
#  'summit',
#  'finally',
#  'glenn',
#  'business',
#  'anthony',
#  'gone',
#  'investigated',
#  'he',
#  'chain',
#  'earning',
#  'laura',
#  'smoke',
#  'form',
#  'sailors',
#  'afroz',
#  'share',
#  'she',
#  'coroner',
#  'cahill',
#  'president',
#  'razzano',
#  'ansett',
#  'mujaheddin',
#  'lowest',
#  'players',
#  'forget',
#  'answer',
#  'queensland',
#  'arrivals',
#  'sanctuary',
#  'separated',
#  'history',
#  'seamaster',
#  'trouble',
#  'eve',
#  'vice',
#  'auckland',
#  'pipeline',
#  'three',
#  'established',
#  'respond',
#  'main',
#  'recommendations',
#  'certain',
#  'judge',
#  'real',
#  'bakes',
#  'big',
#  'neck',
#  'stealing',
#  'farina',
#  'economist',
#  'requested',
#  'unpredictable',
#  'injuring',
#  'neighbouring',
#  'obese',
#  'what',
#  'journey',
#  'poor',
#  'games',
#  'run',
#  'jobs',
#  'hours',
#  'education',
#  'defendant',
#  'first',
#  'threatening',
#  'contract',
#  'ms',
#  'raises',
#  'factions',
#  'picton',
#  'among',
#  'aboard',
#  'efforts',
#  'complaint',
#  'austrade',
#  'best',
#  'attended',
#  'older',
#  'neither',
#  'ron',
#  'break',
#  'music',
#  'defuse',
#  'maker',
#  'kashmir',
#  'willingness',
#  'learn',
#  'hume',
#  'bbc',
#  'agree',
#  'ill',
#  'hoping',
#  'overs',
#  'leaked',
#  'hendriks',
#  'downer',
#  'allowed',
#  'fresh',
#  'offences',
#  'affected',
#  'revealed',
#  'driven',
#  'combination',
#  'winter',
#  'underfoot',
#  'couldn',
#  'heading',
#  'servant',
#  'talk',
#  'confirm',
#  'inspector',
#  'ambush',
#  'satellite',
#  'supporter',
#  'things',
#  'drama',
#  'borders',
#  'female',
#  'republic',
#  'annan',
#  'largely',
#  'four',
#  'unions',
#  'tonnes',
#  'available',
#  'threaten',
#  'you',
#  'reaction',
#  'immigration',
#  'factor',
#  'terror',
#  'cathedral',
#  'line',
#  'burhanuddin',
#  'unexpected',
#  'payne',
#  'district',
#  'allowing',
#  'defeated',
#  'elections',
#  'captain',
#  'appears',
#  'enemy',
#  'penalties',
#  'august',
#  'men',
#  'division',
#  'mcafee',
#  'tangible',
#  'western',
#  'failed',
#  'video',
#  'october',
#  'ministers',
#  'steve',
#  'stock',
#  'changes',
#  'creditors',
#  'vehicles',
#  'burden',
#  'rushed',
#  'crowd',
#  'powell',
#  'china',
#  'measured',
#  'lieutenant',
#  'hill',
#  'decade',
#  'seemed',
#  'shadow',
#  'paktika',
#  'professional',
#  'francs',
#  'tribute',
#  'being',
#  'lionel',
#  'buried',
#  'soldiers',
#  'spiritual',
#  'chinese',
#  'reduce',
#  'monica',
#  'trounson',
#  'begin',
#  'represents',
#  'continuing',
#  'science',
#  'introduce',
#  'beat',
#  'known',
#  'adams',
#  'walked',
#  'push',
#  'extremists',
#  'dewar',
#  'seeking',
#  'bowled',
#  'useful',
#  'spot',
#  'king',
#  'hundreds',
#  'path',
#  'rafter',
#  'convince',
#  'export',
#  'black',
#  'federal',
#  'britain',
#  'highlands',
#  're',
#  'travelled',
#  'accord',
#  'setting',
#  'shell',
#  'served',
#  'extent',
#  'regulation',
#  'concerns',
#  'council',
#  'leave',
#  'mind',
#  'dixon',
#  'pennsylvania',
#  'governance',
#  'verdict',
#  'commonwealth',
#  'crashing',
#  'seven',
#  'olivier',
#  'finalised',
#  'practices',
#  'govern',
#  'successfully',
#  'wearing',
#  'stable',
#  'stronger',
#  'transferred',
#  'fawzi',
#  'ambassador',
#  'putting',
#  'undertaken',
#  'paedophiles',
#  'rejects',
#  'asylum',
#  'identify',
#  'paper',
#  'counting',
#  'costs',
#  'terrorism',
#  'kirribilli',
#  'electricity',
#  'warm',
#  'almost',
#  'penalty',
#  'self',
#  'regime',
#  'bichel',
#  'pitched',
#  'book',
#  'changed',
#  'larrakia',
#  'gunman',
#  'tevake',
#  'chairman',
#  'pressed',
#  'dangerous',
#  'gas',
#  'biological',
#  'submitted',
#  'macgill',
#  'involve',
#  'regulatory',
#  'raids',
#  'nominate',
#  'clement',
#  'hardliners',
#  'thorough',
#  'upper',
#  'due',
#  'conduct',
#  'moment',
#  'jewish',
#  'presidency',
#  'injured',
#  'vote',
#  'tyco',
#  'rich',
#  'tennis',
#  'wide',
#  'mugabe',
#  'second',
#  'abortion',
#  'launched',
#  'role',
#  'yuri',
#  'beatle',
#  'payment',
#  'appropriate',
#  'prosecution',
#  'augusta',
#  'prisoners',
#  'list',
#  'facing',
#  'peter',
#  'ready',
#  'injury',
#  'ravaged',
#  'ordered',
#  'calls',
#  'bush',
#  'pick',
#  'greatest',
#  'whereabouts',
#  'slightly',
#  'surprised',
#  'cross',
#  'during',
#  'parents',
#  'email',
#  'province',
#  'mohamad',
#  'indonesia',
#  'substantial',
#  ...}

# %%
def tidy_sentence(sentence, vocabulary):
    return [word for word in simple_preprocess(sentence) if word in vocabulary]

# %%
sen1=tidy_sentence('A consumer survey will help you understand your customers’ likes, dislikes, and where you need to make improvements. For example, what does the average customer think about your prices? Too high? Just right? How well is your staff doing on customer service, or how well does your client success team understand the growing needs of your customers—and prospects?',model.wv.vocab)

# %%
sen2=tidy_sentence('Employee surveys are valuable for learning about several topics, all of them directly related to employee morale, satisfaction, and involvement with the company.Health benefits, wellness programs, compensation, managers’ performance, career development, work environment: These are all areas you can investigate in depth with a well-designed employee satisfaction survey.',model.wv.vocab)

# %%
sen3=tidy_sentence('Provide better care for your patients. From collecting patient feedback to getting input from staff, our healthcare surveys can get you the answers you need to make improvements across your organization. You can even collect protected health information by turning on HIPAA-compliant features.',model.wv.vocab)

# %%
model.n_similarity(sen1,sen3)
# Out:
# /home/infyblr/anaconda3/envs/surveybrain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `n_similarity` (Method will be removed in 4.0.0, use self.wv.n_similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.966503

# %%
model.n_similarity(sen2,sen3)
# Out:
# /home/infyblr/anaconda3/envs/surveybrain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `n_similarity` (Method will be removed in 4.0.0, use self.wv.n_similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.89485955

# %%
import json

# %%
with open('surveys.json', 'r') as f:
        datastore = json.load(f)

# %%
len(datastore)
# Out:
# 10

# %%
l = [None] * len(datastore)
for key,value in datastore.items():
    l[int(key)-1]=value["description"]

# %%
l
# Out:
# ['The general purpose of customer satisfaction surveys is to assess how satisfied your customers are with different aspects of your product/service. Identifying unhappy customers is as important as identifying extremely happy ones (potential advocates).Having (and maintaining) happy customers improves the odds of repeat purchases as well as raises your general customer lifetime value.Unhappy customers, on the other hand, can be a lot more harmful than you think. Ask them to rate their satisfaction with a specific aspect on a 1 to 10 scale.Using scales to measure customer satisfaction makes it a lot more practical to measure changes in satisfaction over time. That’s even more important when trying to measure the impact of a specific initiative.Measuring and tracking your overall customer satisfaction is the first and most important step towards creating amazing experiences. Keep that in mind, always, and you’ll be on the right path towards developing an awesome product/service.',
#  'An Employee Engagement Survey measures the degree to which employees feel valued at your company. Tracking employee engagement is important in determining whether or not your employees are happy and how long they’ll stay with your company.The questions in an engagement survey are directed towards an organization’s employees to understand their level of engagement with the organization at large, because happy customers are the result of happy employees. Engaged employees will help you get more customers while your disengaged employees will cost you customers: this is the main reason why all world-class winning companies value their work culture.',
#  'A concept testing survey enables you to test an idea or concept before introducing a product or service into the market. For a product or service to be successful in your target market, it is important to understand whether it will be well-accepted by your clientele or not.',
#  'The Net Promoter Score is an index ranging from -100 to 100 that measures the willingness of customers to recommend a company’s products or services to others. It is used as a proxy for gauging the customer’s overall satisfaction with a company’s product or service and the customer’s loyalty to the brand.',
#  'Customer feedback is information provided by clients about whether they are satisfied or dissatisfied with a product or service and about general experience they had with a company. Their opinion is a resource for improving customer experience and adjusting your actions to their needs.For software and apps this is specially important since you need to be aware of what your users like and what the dont to retain their intrest',
#  'This survey is an opportunity for you to evaluate your instructor. The information you provide will be given to the instructor after grades have been reported and will be used to improve classroom performance.',
#  'Website feedback surveys are an online marketing technique for collecting qualitative data from visitors or customers. They are delivered to users directly on the website and they pose a series of questions related to a specific topic that visitors should provide answers to. The data collected by the surveys is then interpreted with the aim of improving the product, service or user experience. Feedback surveys are one of the best ways to find out what customers like or dislike about a website, product or service. There are other indirect methods of finding out what visitors prefer such as heat maps, click maps or session recordings but their interpretation is subject to an increased degree of subjectivity from the marketers overseeing the project.',
#  'Event feedback survey questions are survey questions asked after an event has concluded to the attendees to understand their opinions about the event. Every attendee has a unique experience during the event because of which it is important to understand each individual’s opinion. These survey questions can be asked for public events, training courses, conferences, conclaves, exhibitions, and webinars. Using these survey questions the researcher can collect objective and actionable feedback that can be used to host much better events in the future and provide satisfaction to its attendees.',
#  'Our online meeting feedback survey form asks for candid responses about the meeting recently attended. Just how productive did attendees feel the meeting was? Exactly why do they feel that way? Were the meeting objectives clearly communicated in advance? Were they met? Were follow-up actions decided on and assigned? How well was the meeting moderated? You can also find out if attendees feel they had the opportunity to participate in the meeting--and if all the right people were invited to attend. Our meeting feedback questionnaire even gives attendees an opportunity to assess the meeting logistics, timeliness, and overall effectiveness of the meeting. Taking time to find out how attendees feel about a meeting afterwards can help you plan more focused and effective meetings for the next time!',
#  'Volunteer activities are just like any other event: You won’t know what people liked (or didn’t like) unless you ask them. When you have a list of people who just devoted their time to your cause, the experience is fresh in their minds, and they’re bound to have opinions about it. This is what makes the volunteer satisfaction survey such a powerful tool. By surveying volunteers shortly after their service, you can gain firsthand insights and then use that feedback to improve the experience and boost volunteer registration in the future.']

# %%
desc='To know how the employees feel about their job. To see if the employees are satisfied with the work environment and th get some feedback to improve'

# %%
tidied=[]
for i in l:
    tidied.append(tidy_sentence(i,model.wv.vocab))

# %%
desc=tidy_sentence(desc,model.wv.vocab)

# %%
desc
# Out:
# ['to',
#  'know',
#  'how',
#  'the',
#  'employees',
#  'feel',
#  'about',
#  'their',
#  'job',
#  'to',
#  'see',
#  'if',
#  'the',
#  'employees',
#  'are',
#  'satisfied',
#  'with',
#  'the',
#  'work',
#  'environment',
#  'and',
#  'th',
#  'get',
#  'some',
#  'to',
#  'improve']

# %%
model.n_similarity(desc,tidied[0])
# Out:
# /home/infyblr/anaconda3/envs/surveybrain/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `n_similarity` (Method will be removed in 4.0.0, use self.wv.n_similarity() instead).
#   """Entry point for launching an IPython kernel.
# 0.9391995

# %%
tidied[5]
# Out:
# ['is',
#  'information',
#  'provided',
#  'by',
#  'about',
#  'whether',
#  'they',
#  'are',
#  'satisfied',
#  'or',
#  'with',
#  'or',
#  'service',
#  'and',
#  'about',
#  'general',
#  'experience',
#  'they',
#  'had',
#  'with',
#  'company',
#  'their',
#  'opinion',
#  'is',
#  'for',
#  'experience',
#  'and',
#  'your',
#  'actions',
#  'to',
#  'their',
#  'needs',
#  'for',
#  'software',
#  'and',
#  'this',
#  'is',
#  'important',
#  'since',
#  'you',
#  'need',
#  'to',
#  'be',
#  'aware',
#  'of',
#  'what',
#  'your',
#  'users',
#  'like',
#  'and',
#  'what',
#  'the',
#  'to',
#  'their']

# %%
import gensim.corpora.wikicorpus as wiki

# %%
wiki
# Out:
# <module 'gensim.corpora.wikicorpus' from '/home/infyblr/anaconda3/envs/surveybrain/lib/python3.6/site-packages/gensim/corpora/wikicorpus.py'>
